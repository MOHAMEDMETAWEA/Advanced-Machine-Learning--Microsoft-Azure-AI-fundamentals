# %% [markdown]
# # Import Required Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Machine learning 2024/Notebooks - ANN - DNN/11.Auto encoder/Denoising dentists project
# Out:
# /content/drive/MyDrive/Machine learning 2024/Notebooks - ANN - DNN/11.Auto encoder/Denoising dentists project

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, Input, MaxPooling2D, UpSampling2D
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # Load Data

# %%
root_dir = "Dataset/"

# %%
image_paths = os.listdir(root_dir)
len(image_paths)
# Out:
# 120

# %%
images = []

for image_path in image_paths:
    img = load_img(root_dir + image_path, target_size=(64, 64), color_mode="grayscale")
    img = img_to_array(img)
    img = img / 255.
    images.append(img)

# %%
images = np.array(images)

# %%
type(images)
# Out:
# numpy.ndarray

# %%
# plot some images

import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].reshape(64, 64), cmap='gray')
    plt.axis('off')
plt.show()

# %%
noise_factor = 0.2

noise_images = []

for image in images:
    noisy = image + noise_factor * np.random.randn(*image.shape)  # original (64 * 64) + noise (64 * 64)
    noisy = np.clip(noisy, 0., 1.) # normalization  image /255
    noise_images.append(noisy)

# %%
noise_images = np.array(noise_images)

# %%
plt.imshow(images[0], cmap="gray")

# %%
plt.imshow(noise_images[0], cmap="gray")

# %%
noise_train = noise_images[:100]
noise_test = noise_images[100:]

noise_train.shape, noise_test.shape
# Out:
# ((100, 64, 64, 1), (20, 64, 64, 1))

# %%
normal_train = images[:100]
normal_test = images[100:]

normal_train.shape, normal_test.shape
# Out:
# ((100, 64, 64, 1), (20, 64, 64, 1))

# %% [markdown]
# # Models

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, MaxPooling2D,MaxPool2D ,UpSampling2D, Flatten, Input
from keras.optimizers import SGD, Adam, Adadelta, Adagrad
from keras import backend as K

def autoencoder():

    input_img = Input(shape=(64,64,1), name='image_input')

    #enoder
    x = Conv2D(64, (3,3), activation='relu', padding='same', name='Conv1')(input_img)
    x = MaxPooling2D((2,2), padding='same', name='pool1')(x)
    x = Conv2D(64, (3,3), activation='relu', padding='same', name='Conv2')(x)
    x = MaxPooling2D((2,2), padding='same', name='pool2')(x)

    #decoder
    x = Conv2D(64, (3,3), activation='relu', padding='same', name='Conv3')(x)
    x = UpSampling2D((2,2), name='upsample1')(x)
    x = Conv2D(64, (3,3), activation='relu', padding='same', name='Conv4')(x)
    x = UpSampling2D((2,2), name='upsample2')(x)
    x = Conv2D(1, (3,3), activation='sigmoid', padding='same', name='Conv5')(x)

    #model
    autoencoder = Model(inputs=input_img, outputs=x)
    autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

    return autoencoder

# %%
model= autoencoder()
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ image_input (InputLayer)             │ (None, 64, 64, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv1 (Conv2D)                       │ (None, 64, 64, 64)          │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ pool1 (MaxPooling2D)                 │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv2 (Conv2D)                       │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ pool2 (MaxPooling2D)                 │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv3 (Conv2D)                       │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ upsample1 (UpSampling2D)             │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv4 (Conv2D)                       │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ upsample2 (UpSampling2D)             │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv5 (Conv2D)                       │ (None, 64, 64, 1)           │             577 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 112,001 (437.50 KB)
#  Trainable params: 112,001 (437.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(noise_train,
                 normal_train,
                 validation_data=(noise_test, normal_test),
                 epochs=200,
                 batch_size=16)
# Out:
# Epoch 1/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 414ms/step - loss: 0.6864 - val_loss: 0.6340
# Epoch 2/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 560ms/step - loss: 0.6363 - val_loss: 0.6103
# Epoch 3/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 354ms/step - loss: 0.6218 - val_loss: 0.5958
# Epoch 4/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 350ms/step
# Epoch 174/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 442ms/step - loss: 0.5629 - val_loss: 0.5503
# Epoch 175/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 363ms/step - loss: 0.5604 - val_loss: 0.5503
# Epoch 176/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 362ms/step - loss: 0.5637 - val_loss: 0.5499
# Epoch 177/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 520ms/step - loss: 0.5593 - val_loss: 0.5499
# Epoch 178/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 479ms/step - loss: 0.5593 - val_loss: 0.5502
# Epoch 179/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 352ms/step - loss: 0.5658 - val_loss: 0.5498
# Epoch 180/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - loss: 0.5621 - val_loss: 0.5503
# Epoch 181/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 586ms/step - loss: 0.5565 - val_loss: 0.5513
# Epoch 182/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 352ms/step - loss: 0.5585 - val_loss: 0.5516
# Epoch 183/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 336ms/step - loss: 0.5650 - val_loss: 0.5500
# Epoch 184/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 355ms/step - loss: 0.5634 - val_loss: 0.5497
# Epoch 185/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 425ms/step - loss: 0.5574 - val_loss: 0.5507
# Epoch 186/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 348ms/step - loss: 0.5638 - val_loss: 0.5500
# Epoch 187/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 345ms/step - loss: 0.5611 - val_loss: 0.5497
# Epoch 188/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 367ms/step - loss: 0.5601 - val_loss: 0.5498
# Epoch 189/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 638ms/step - loss: 0.5606 - val_loss: 0.5500
# Epoch 190/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 365ms/step - loss: 0.5638 - val_loss: 0.5501
# Epoch 191/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 379ms/step - loss: 0.5584 - val_loss: 0.5497
# Epoch 192/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 610ms/step - loss: 0.5537 - val_loss: 0.5499
# Epoch 193/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 362ms/step - loss: 0.5554 - val_loss: 0.5497
# Epoch 194/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 460ms/step - loss: 0.5628 - val_loss: 0.5499
# Epoch 195/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 480ms/step - loss: 0.5570 - val_loss: 0.5499
# Epoch 196/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 501ms/step - loss: 0.5625 - val_loss: 0.5514
# Epoch 197/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 415ms/step - loss: 0.5567 - val_loss: 0.5506
# Epoch 198/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 354ms/step - loss: 0.5580 - val_loss: 0.5497
# Epoch 199/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 370ms/step - loss: 0.5550 - val_loss: 0.5500
# Epoch 200/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 513ms/step - loss: 0.5583 - val_loss: 0.5498

# %%
predicted = model.predict(noise_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step

# %%
from sklearn.metrics import mean_squared_error
# Calculate Mean Squared Error (MSE)
actual_values_flat = normal_test.flatten()
predicted_values_flat = predicted.flatten()

mse = mean_squared_error(actual_values_flat, predicted_values_flat)

print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.003857574

# %%
evaluation = model.evaluate(noise_test, normal_test)
evaluation
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.5498
# 0.5498127937316895

# %%
def plot_predictions(test, preds):
    plt.figure(figsize=(14, 12))

    # Noise test
    for i in range(16):
        plt.subplot(4, 8, i + 1)
        plt.imshow(test[i], cmap='gray')
        plt.axis('off')
        plt.title('Noised')

    # Predicted
    for i in range(16):
        plt.subplot(4, 8, i + 17)
        plt.imshow(preds[i], cmap='gray')
        plt.axis('off')
        plt.title('Predicted')

    plt.show()

# %%
plot_predictions(noise_test, predicted)

# %%
# how to calculate the PSNR for our data using peak_signal_noise_ratio

import numpy as np
from skimage.metrics import peak_signal_noise_ratio

psnr_values = []
for i in range(len(normal_test)):
  psnr = peak_signal_noise_ratio(normal_test[i], predicted[i])
  psnr_values.append(psnr)

# Calculate the average PSNR
average_psnr = np.mean(psnr_values)
print("Average PSNR:", average_psnr)
# Out:
# Average PSNR: 24.382094725047406

# %%
# average of the RMSE and also average MSE

import numpy as np
from sklearn.metrics import mean_squared_error
from math import sqrt

rmse_values = []
mse_values = []

for i in range(len(normal_test)):
  mse = mean_squared_error(normal_test[i].flatten(), predicted[i].flatten())
  rmse = sqrt(mse)
  rmse_values.append(rmse)
  mse_values.append(mse)

average_rmse = np.mean(rmse_values)
average_mse = np.mean(mse_values)

print("Average RMSE:", average_rmse)
print("Average MSE:", average_mse)
# Out:
# Average RMSE: 0.06123194342766057
# Average MSE: 0.003857574

# %%
input_layer = Input(shape=(64, 64, 1))

# Encoder
x = Conv2D(32, (3, 3), activation="relu", padding="same")(input_layer)
x = MaxPooling2D((2, 2), padding="same")(x)
x = Conv2D(64, (3, 3), activation="relu", padding="same")(x)
encoded = MaxPooling2D((2, 2), padding="same")(x)

# Decoder
x = Conv2D(64, (3, 3), activation="relu", padding="same")(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation="relu", padding="same")(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation="sigmoid", padding="same")(x)

autoencoder2 = Model(input_layer, decoded)

# %%
autoencoder2.compile(optimizer='adam', loss='mean_squared_error')

# %%
autoencoder2.fit(noise_train,
                 normal_train, epochs=150, batch_size=16, shuffle=True, validation_data=(noise_test, normal_test))
# Out:
# Epoch 1/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 244ms/step - loss: 0.0577 - val_loss: 0.0486
# Epoch 2/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - loss: 0.0372 - val_loss: 0.0214
# Epoch 3/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 299ms/step - loss: 0.0210 - val_loss: 0.0200
# Epoch 4/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 348ms/step - loss: 0.0164 - val_loss: 0.0154
# Epoch 5/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 243ms/step - loss: 0.0141 - val_loss: 0.0136
# Epoch 6/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 0.0118 - val_loss: 0.0115
# Epoch 7/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - loss: 0.0108 - val_loss: 0.0123
# Epoch 8/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 231ms/step - loss: 0.0103 - val_loss: 0.0098
# Epoch 9/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step - loss: 0.0090 - val_loss: 0.0095
# Epoch 10/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 364ms/step - loss: 0.0086 - val_loss: 0.0109
# Epoch 11/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 206ms/step - loss: 0.0091 - val_loss: 0.0080
# Epoch 12/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - loss: 0.0079 - val_loss: 0.0076
# Epoch 13/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 217ms/step - loss: 0.0072 - val_loss: 0.0072
# Epoch 14/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - loss: 0.0067 - val_loss: 0.0070
# Epoch 15/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step - loss: 0.0066 - val_loss: 0.0077
# Epoch 16/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 363ms/step - loss: 0.0070 - val_loss: 0.0073
# Epoch 17/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 205ms/step - loss: 0.0068 - val_loss: 0.0064
# Epoch 18/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - loss: 0.0062 - val_loss: 0.0064
# Epoch 19/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - loss: 0.0062 - val_loss: 0.0066
# Epoch 20/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 214ms/step - loss: 0.0068 - val_loss: 0.0074
# Epoch 21/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 323ms/step - loss: 0.0066 - val_loss: 0.0075
# Epoch 22/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 349ms/step - loss: 0.0066 - val_loss: 0.0070
# Epoch 23/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step - loss: 0.0066 - val_loss: 0.0060
# Epoch 24/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 410ms/step - loss: 0.0058 - val_loss: 0.0059
# Epoch 25/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 466ms/step - loss: 0.0058 - val_loss: 0.0058
# Epoch 26/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 366ms/step - loss: 0.0057 - val_loss: 0.0059
# Epoch 27/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 631ms/step - loss: 0.0056 - val_loss: 0.0057
# Epoch 28/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 372ms/step - loss: 0.0054 - val_loss: 0.0057
# Epoch 29/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 212ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 30/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - loss: 0.0054 - val_loss: 0.0055
# Epoch 31/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 314ms/step - loss: 0.0051 - val_loss: 0.0055
# Epoch 32/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 340ms/step - loss: 0.0051 - val_loss: 0.0057
# Epoch 33/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - loss: 0.0061 - val_loss: 0.0058
# Epoch 34/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - loss: 0.0058 - val_loss: 0.0060
# Epoch 35/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 215ms/step - loss: 0.0054 - val_loss: 0.0057
# Epoch 36/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - loss: 0.0052 - val_loss: 0.0058
# Epoch 37/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 213ms/step - loss: 0.0054 - val_loss: 0.0053
# Epoch 38/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 308ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 39/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 351ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 40/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 196ms/step - loss: 0.0051 - val_loss: 0.0055
# Epoch 41/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - loss: 0.0052 - val_loss: 0.0051
# Epoch 42/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - loss: 0.0047 - val_loss: 0.0052
# Epoch 43/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step - loss: 0.0049 - val_loss: 0.0051
# Epoch 44/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 286ms/step - loss: 0.0048 - val_loss: 0.0055
# Epoch 45/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 368ms/step - loss: 0.0049 - val_loss: 0.0051
# Epoch 46/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 396ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 47/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 244ms/step - loss: 0.0047 - val_loss: 0.0050
# Epoch 48/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - loss: 0.0048 - val_loss: 0.0051
# Epoch 49/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - loss: 0.0047 - val_loss: 0.0050
# Epoch 50/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step - loss: 0.0047 - val_loss: 0.0051
# Epoch 51/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 354ms/step - loss: 0.0048 - val_loss: 0.0050
# Epoch 52/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 355ms/step - loss: 0.0047 - val_loss: 0.0049
# Epoch 53/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step - loss: 0.0047 - val_loss: 0.0049
# Epoch 54/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - loss: 0.0046 - val_loss: 0.0051
# Epoch 55/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - loss: 0.0048 - val_loss: 0.0050
# Epoch 56/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 215ms/step - loss: 0.0046 - val_loss: 0.0050
# Epoch 57/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 221ms/step - loss: 0.0046 - val_loss: 0.0048
# Epoch 58/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 309ms/step - loss: 0.0046 - val_loss: 0.0053
# Epoch 59/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - loss: 0.0044 - val_loss: 0.0049
# Epoch 60/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 274ms/step - loss: 0.0048 - val_loss: 0.0048
# Epoch 61/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - loss: 0.0045 - val_loss: 0.0047
# Epoch 62/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 207ms/step - loss: 0.0044 - val_loss: 0.0048
# Epoch 63/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - loss: 0.0044 - val_loss: 0.0049
# Epoch 64/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 207ms/step - loss: 0.0045 - val_loss: 0.0049
# Epoch 65/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step - loss: 0.0046 - val_loss: 0.0053
# Epoch 66/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 326ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 67/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 333ms/step - loss: 0.0045 - val_loss: 0.0047
# Epoch 68/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 266ms/step - loss: 0.0044 - val_loss: 0.0048
# Epoch 69/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - loss: 0.0045 - val_loss: 0.0048
# Epoch 70/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 211ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 71/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 219ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 72/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 73/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 349ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 74/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 357ms/step - loss: 0.0042 - val_loss: 0.0045
# Epoch 75/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step - loss: 0.0041 - val_loss: 0.0046
# Epoch 76/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 207ms/step - loss: 0.0042 - val_loss: 0.0045
# Epoch 77/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step - loss: 0.0041 - val_loss: 0.0045
# Epoch 78/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - loss: 0.0041 - val_loss: 0.0044
# Epoch 79/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - loss: 0.0040 - val_loss: 0.0044
# Epoch 80/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 361ms/step - loss: 0.0039 - val_loss: 0.0044
# Epoch 81/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 206ms/step - loss: 0.0039 - val_loss: 0.0044
# Epoch 82/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - loss: 0.0039 - val_loss: 0.0045
# Epoch 83/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 195ms/step - loss: 0.0040 - val_loss: 0.0047
# Epoch 84/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - loss: 0.0041 - val_loss: 0.0043
# Epoch 85/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 327ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 86/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 249ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 87/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 88/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 89/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 211ms/step - loss: 0.0038 - val_loss: 0.0042
# Epoch 90/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step - loss: 0.0038 - val_loss: 0.0042
# Epoch 91/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 337ms/step - loss: 0.0036 - val_loss: 0.0042
# Epoch 92/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 335ms/step - loss: 0.0038 - val_loss: 0.0046
# Epoch 93/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - loss: 0.0040 - val_loss: 0.0045
# Epoch 94/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - loss: 0.0039 - val_loss: 0.0042
# Epoch 95/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - loss: 0.0038 - val_loss: 0.0042
# Epoch 96/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - loss: 0.0036 - val_loss: 0.0042
# Epoch 97/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 98/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 352ms/step - loss: 0.0038 - val_loss: 0.0042
# Epoch 99/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 321ms/step - loss: 0.0036 - val_loss: 0.0042
# Epoch 100/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 101/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 197ms/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 102/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 103/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 207ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 104/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 105/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 355ms/step - loss: 0.0036 - val_loss: 0.0042
# Epoch 106/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 276ms/step - loss: 0.0036 - val_loss: 0.0042
# Epoch 107/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 108/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - loss: 0.0037 - val_loss: 0.0044
# Epoch 109/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 207ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 110/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 216ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 111/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 267ms/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 112/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 324ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 113/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - loss: 0.0035 - val_loss: 0.0042
# Epoch 114/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 115/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 0.0033 - val_loss: 0.0041
# Epoch 116/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 117/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 291ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 118/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 371ms/step - loss: 0.0036 - val_loss: 0.0040
# Epoch 119/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 341ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 120/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - loss: 0.0035 - val_loss: 0.0042
# Epoch 121/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 122/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 123/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 225ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 124/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 125/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - loss: 0.0035 - val_loss: 0.0045
# Epoch 126/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 360ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 127/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - loss: 0.0034 - val_loss: 0.0040
# Epoch 128/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 129/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - loss: 0.0034 - val_loss: 0.0040
# Epoch 130/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 131/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 218ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 132/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 350ms/step - loss: 0.0033 - val_loss: 0.0041
# Epoch 133/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 214ms/step - loss: 0.0034 - val_loss: 0.0041
# Epoch 134/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 260ms/step - loss: 0.0034 - val_loss: 0.0040
# Epoch 135/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 370ms/step - loss: 0.0034 - val_loss: 0.0040
# Epoch 136/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - loss: 0.0032 - val_loss: 0.0040
# Epoch 137/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 355ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 138/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 314ms/step - loss: 0.0033 - val_loss: 0.0041
# Epoch 139/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - loss: 0.0034 - val_loss: 0.0040
# Epoch 140/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 141/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 212ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 142/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 143/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 338ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 144/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 250ms/step - loss: 0.0032 - val_loss: 0.0040
# Epoch 145/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 146/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 147/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - loss: 0.0032 - val_loss: 0.0040
# Epoch 148/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 213ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 149/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 343ms/step - loss: 0.0032 - val_loss: 0.0042
# Epoch 150/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 253ms/step - loss: 0.0035 - val_loss: 0.0040

# %%
predicted = autoencoder2.predict(noise_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step

# %%
evaluation = autoencoder2.evaluate(noise_test, normal_test)
evaluation
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0040
# 0.003955517895519733

# %%
# how to calculate the PSNR for our data using peak_signal_noise_ratio

import numpy as np
from skimage.metrics import peak_signal_noise_ratio

psnr_values = []
for i in range(len(normal_test)):
  psnr = peak_signal_noise_ratio(normal_test[i], predicted[i])
  psnr_values.append(psnr)

# Calculate the average PSNR
average_psnr = np.mean(psnr_values)
print("Average PSNR:", average_psnr)
# Out:
# Average PSNR: 24.2836755753191

# %%
# average of the RMSE and also average MSE

import numpy as np
from sklearn.metrics import mean_squared_error
from math import sqrt

rmse_values = []
mse_values = []

for i in range(len(normal_test)):
  mse = mean_squared_error(normal_test[i].flatten(), predicted[i].flatten())
  rmse = sqrt(mse)
  rmse_values.append(rmse)
  mse_values.append(mse)

average_rmse = np.mean(rmse_values)
average_mse = np.mean(mse_values)

print("Average RMSE:", average_rmse)
print("Average MSE:", average_mse)
# Out:
# Mean Squared Error: 0.003955518

# %%
plot_predictions(noise_test, predicted)
