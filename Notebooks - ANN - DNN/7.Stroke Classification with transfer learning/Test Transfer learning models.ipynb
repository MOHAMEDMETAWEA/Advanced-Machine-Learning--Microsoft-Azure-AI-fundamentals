# %%
import keras
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = 'source.jpeg'
img = keras.utils.load_img(img_path, target_size=(224, 224))
x = keras.utils.img_to_array(img)
x = np.expand_dims(x, axis=0) # (224, 224, 3 )  => (1, 224, 224, 3 )
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=10)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Predicted: [('n02389026', 'sorrel', 0.6169472), ('n02113978', 'Mexican_hairless', 0.09517299), ('n03803284', 'muzzle', 0.059747458), ('n02109047', 'Great_Dane', 0.046623494), ('n02087394', 'Rhodesian_ridgeback', 0.0212703), ('n02108089', 'boxer', 0.016194543), ('n02422106', 'hartebeest', 0.011504313), ('n02088466', 'bloodhound', 0.0055066063), ('n02090379', 'redbone', 0.0051043946), ('n02417914', 'ibex', 0.0047322153)]
